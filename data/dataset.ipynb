# %%
import pandas as pd

dataset_path = './synthetic-it-call-center-tickets.csv'
small_dataset_path = './synthetic-it-call-center-tickets-small.csv'

# %%
df = pd.read_csv(dataset_path)

# %%
small_df = df.sample(n=1000, random_state=42)
small_df.to_csv(small_dataset_path, index=False)
